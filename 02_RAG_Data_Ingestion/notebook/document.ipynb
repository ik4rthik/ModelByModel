# %%
from langchain_core.documents import Document

# %%
doc= Document(
    page_content="this the the page content im using to create my first rag project",
metadata={
    "source":"example.txt",
    "author":"karthik",
    "pages":1,
    "date_created":2026-3-15


    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'author': 'karthik', 'pages': 1, 'date_created': 2008}, page_content='this the the page content im using to create my first rag project')

# %%
import os
os.makedirs("../data/text_files", exist_ok=True)
os.makedirs("../data/pdf", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction
    Python is a popular, high-level, interpreted programming language designed by Guido van Rossum and released in 1991. It is heavily focused on code readability and clean syntax, allowing you to accomplish complex operations with fewer lines of code than languages like C++ or Java. Key Features of Python: Interpreted language that executes line-by-line. Dynamically typed with automatic type tracking. Cross-platform compatibility across Windows, Mac, Linux, and Raspberry Pi. Multi-paradigm supporting procedural, object-oriented, and functional programming.""",
    
    "../data/text_files/machine_learning.txt":"""Machine Learning Fundamentals
    Machine Learning is a subset of artificial intelligence that enables systems to learn and improve from experience without being explicitly programmed. It focuses on developing algorithms that can access data and use it to learn for themselves. Types of Machine Learning: Supervised Learning uses labeled data to train models. Unsupervised Learning finds patterns in unlabeled data. Reinforcement Learning learns through interaction with an environment. Common Applications: Predictive analytics, recommendation systems, image recognition, natural language processing, anomaly detection, and autonomous systems."""
}

for file_path, content in sample_texts.items():
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(content)
print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/example.txt", encoding="utf-8")
documents = loader.load() 
print(documents)
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_25548\3474102941.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader("../data/text_files", glob="*.txt", loader_cls=TextLoader, loader_kwargs={"encoding": "utf-8"}, show_progress=True)
documents=dir_loader.load()
print(documents)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 1459.90it/s]
# ...

# %%
from langchain_community.document_loaders import PyMuPDFLoader

dir_loader = DirectoryLoader("../data/pdf", glob="*.pdf", loader_cls=PyMuPDFLoader, show_progress=True)
pdf_documents=dir_loader.load()
pdf_documents
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 291.63it/s]
# ...
